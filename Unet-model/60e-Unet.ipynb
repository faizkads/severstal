# %%
#for data processing
import os
import json
import keras
import numpy as np
import pandas as pd
import cv2
from tqdm import tqdm
from sklearn.model_selection import train_test_split

#for U-net model
from keras import backend as K
from keras.models import Model
from keras.layers import Input
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.losses import binary_crossentropy
from keras.callbacks import Callback, ModelCheckpoint

# %% [markdown]
# > # Load Pre-processed Data

# %%
train_df = pd.read_csv('../input/editeddata/train_df.csv')
test_df = pd.read_csv('../input/editeddata/test_df.csv')

# %%
train_df['ImageId'] = train_df['ImageId_ClassId'].apply(lambda x: x.split('_')[0])
train_df['ClassId'] = train_df['ImageId_ClassId'].apply(lambda x: x.split('_')[1])
train_df['hasMask'] = ~ train_df['EncodedPixels'].isna()
train_df.head()
# Out:
#    ImageId_ClassId                                      EncodedPixels  \
# 0  0002cc93b.jpg_1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0002cc93b.jpg_2                                                NaN
# 2  0002cc93b.jpg_3                                                NaN
# 3  0002cc93b.jpg_4                                                NaN
# 4  00031f466.jpg_1                                                NaN
#
#          ImageId ClassId  hasMask
# 0  0002cc93b.jpg       1     True
# 1  0002cc93b.jpg       2    False
# 2  0002cc93b.jpg       3    False
# 3  0002cc93b.jpg       4    False
# 4  00031f466.jpg       1    False

# %%
mask_count_df = train_df.groupby('ImageId').agg(np.sum).reset_index()
mask_count_df.sort_values('hasMask', ascending=False, inplace=True)
# print(mask_count_df.shape)
mask_count_df.head()
# Out:
#              ImageId  hasMask
# 10803  db4867ee8.jpg      3.0
# 11776  ef24da2ba.jpg      3.0
# 6284   7f30b9c64.jpg      2.0
# 9421   bf0c81db6.jpg      2.0
# 9615   c314f43f3.jpg      2.0

# %%
train_df.head()
# Out:
#    ImageId_ClassId                                      EncodedPixels  \
# 0  0002cc93b.jpg_1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0002cc93b.jpg_2                                                NaN
# 2  0002cc93b.jpg_3                                                NaN
# 3  0002cc93b.jpg_4                                                NaN
# 4  00031f466.jpg_1                                                NaN
#
#          ImageId ClassId  hasMask
# 0  0002cc93b.jpg       1     True
# 1  0002cc93b.jpg       2    False
# 2  0002cc93b.jpg       3    False
# 3  0002cc93b.jpg       4    False
# 4  00031f466.jpg       1    False

# %% [markdown]
# # **submission data**

# %%
sub_df_origin = pd.read_csv('../input/severstal-steel-defect-detection/sample_submission.csv')
sub_df_origin.head()
# Out:
#          ImageId EncodedPixels  ClassId
# 0  0000f269f.jpg      1 409600        0
# 1  000ccc2ac.jpg      1 409600        0
# 2  002451917.jpg      1 409600        0
# 3  003c5da97.jpg      1 409600        0
# 4  0042e163f.jpg      1 409600        0

# %%
sub_df = pd.DataFrame(columns=['ImageId_ClassId','EncodedPixels'])
for i in tqdm(range(len(sub_df_origin))):
    for j in range(4):
        tmp_se = pd.Series( [sub_df_origin['ImageId'][i]+'_{}'.format(j+1),None], index=sub_df.columns )
        sub_df = sub_df.append( tmp_se, ignore_index=True )
sub_df['ImageId'] = sub_df['ImageId_ClassId'].apply(lambda x: x.split('_')[0])
sub_df.head()
# Out:
# 100%|██████████| 5506/5506 [00:33<00:00, 166.13it/s]
#    ImageId_ClassId EncodedPixels        ImageId
# 0  0000f269f.jpg_1          None  0000f269f.jpg
# 1  0000f269f.jpg_2          None  0000f269f.jpg
# 2  0000f269f.jpg_3          None  0000f269f.jpg
# 3  0000f269f.jpg_4          None  0000f269f.jpg
# 4  000ccc2ac.jpg_1          None  000ccc2ac.jpg

# %%
test_df = pd.DataFrame(sub_df['ImageId'].unique(), columns=['ImageId'])

# %%
test_df.head()
# Out:
#             ImageId
# 0     0000f269f.jpg
# 1     000ccc2ac.jpg
# 2     002451917.jpg
# 3     003c5da97.jpg
# 4     0042e163f.jpg
# 5     004f40c73.jpg
# 6     00513039a.jpg
# 7     006f39c41.jpg
# 8     008725cbc.jpg
# 9     0098ca44e.jpg
# 10    00a0b7730.jpg
# 11    00a0f9949.jpg
# 12    00b000b81.jpg
# 13    00b7fb703.jpg
# 14    00bbcd9af.jpg
# 15    00d72c660.jpg
# 16    00df5b714.jpg
# 17    00f3799a7.jpg
# 18    0108ce457.jpg
# 19    0109b68ec.jpg
# 20    010ec96b4.jpg
# 21    011a7e2a9.jpg
# 22    0126f74ef.jpg
# 23    012754bbb.jpg
# 24    01588ee42.jpg
# 25    015be539e.jpg
# 26    017796c88.jpg
# 27    017bd7ce3.jpg
# 28    018d7b0a1.jpg
# 29    019258298.jpg
# ...             ...
# 5476  fec39dc8f.jpg
# 5477  fed4c950f.jpg
# 5478  fed9a49cc.jpg
# 5479  ff18d8aa8.jpg
# 5480  ff195b996.jpg
# 5481  ff390556f.jpg
# 5482  ff425374d.jpg
# 5483  ff4d29e0d.jpg
# 5484  ff4db885a.jpg
# 5485  ff55577a8.jpg
# 5486  ff55d7c18.jpg
# 5487  ff57de822.jpg
# 5488  ff5983d36.jpg
# 5489  ff5f30cea.jpg
# 5490  ff6aa9608.jpg
# 5491  ff6b5bf9d.jpg
# 5492  ff740a9be.jpg
# 5493  ff77b45cc.jpg
# 5494  ff82f0901.jpg
# 5495  ff8ada2b4.jpg
# 5496  ffa10f6f3.jpg
# 5497  ffabb7aa2.jpg
# 5498  ffaf13d96.jpg
# 5499  ffb2e783d.jpg
# 5500  ffbf79783.jpg
# 5501  ffc9a6187.jpg
# 5502  ffdb60677.jpg
# 5503  ffe6e2da6.jpg
# 5504  fff4fd9bb.jpg
# 5505  fff598023.jpg
#
# [5506 rows x 1 columns]

# %% [markdown]
# > # Utility Functions

# %% [markdown]
# ## RLE Mask Encoding and Decoding
# Source: [RLE Functions by Paulo Pinto](http://https://www.kaggle.com/code/paulorzp/rle-functions-run-lenght-encode-decode/script)

# %%
def mask2rle(img):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels= img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def rle2mask(mask_rle, shape=(256,1600)):
    '''
    mask_rle: run-length as string formated (start length)
    shape: (width,height) of array to return 
    Returns numpy array, 1 - mask, 0 - background

    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T

# %%
def build_masks(rles, input_shape):
    depth = len(rles)
    height, width = input_shape
    masks = np.zeros((height, width, depth))
    
    for i, rle in enumerate(rles):
        if type(rle) is str:
            masks[:, :, i] = rle2mask(rle, (width, height))
    
    return masks

def build_rles(masks):
    width, height, depth = masks.shape
    
    rles = [mask2rle(masks[:, :, i])
            for i in range(depth)]
    
    return rles

# %% [markdown]
# ## Loss function

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %% [markdown]
# # Data Generator

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, df, target_df=None, mode='fit',
                 base_path='../input/severstal-steel-defect-detection/train_images',
                 batch_size=32, dim=(256, 1600), n_channels=1,
                 n_classes=4, random_state=2019, shuffle=True):
        self.dim = dim
        self.batch_size = batch_size
        self.df = df
        self.mode = mode
        self.base_path = base_path
        self.target_df = target_df
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.random_state = random_state
        
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_batch = [self.list_IDs[k] for k in indexes]
        
        X = self.__generate_X(list_IDs_batch)
        
        if self.mode == 'fit':
            y = self.__generate_y(list_IDs_batch)
            return X, y
        
        elif self.mode == 'predict':
            return X

        else:
            raise AttributeError('The mode parameter should be set to "fit" or "predict".')
        
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.seed(self.random_state)
            np.random.shuffle(self.indexes)
    
    def __generate_X(self, list_IDs_batch):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        
        # Generate data
        for i, ID in enumerate(list_IDs_batch):
            im_name = self.df['ImageId'].iloc[ID]
            img_path = f"{self.base_path}/{im_name}"
            img = self.__load_grayscale(img_path)
            
            # Store samples
            X[i,] = img

        return X
    
    def __generate_y(self, list_IDs_batch):
        y = np.empty((self.batch_size, *self.dim, self.n_classes), dtype=int)
        
        for i, ID in enumerate(list_IDs_batch):
            im_name = self.df['ImageId'].iloc[ID]
            image_df = self.target_df[self.target_df['ImageId'] == im_name]
            
            rles = image_df['EncodedPixels'].values
            masks = build_masks(rles, input_shape=self.dim)
            
            y[i, ] = masks

        return y
    
    def __load_grayscale(self, img_path):
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = img.astype(np.float32) / 255.
        img = np.expand_dims(img, axis=-1)

        return img
    
    def __load_rgb(self, img_path):
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = img.astype(np.float32) / 255.

        return img

# %%
BATCH_SIZE = 16

train_idx, val_idx = train_test_split(
    mask_count_df.index, random_state=2019, test_size=0.15
)

train_generator = DataGenerator(
    train_idx, 
    df=mask_count_df,
    target_df=train_df,
    batch_size=BATCH_SIZE, 
    n_classes=4
)

val_generator = DataGenerator(
    val_idx, 
    df=mask_count_df,
    target_df=train_df,
    batch_size=BATCH_SIZE, 
    n_classes=4
)

# %% [markdown]
# # Model Architecture

# %%
def build_model(input_shape):
    inputs = Input(input_shape)

    c1 = Conv2D(8, (3, 3), activation='elu', padding='same') (inputs)
    c1 = Conv2D(8, (3, 3), activation='elu', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = Conv2D(16, (3, 3), activation='elu', padding='same') (p1)
    c2 = Conv2D(16, (3, 3), activation='elu', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(32, (3, 3), activation='elu', padding='same') (p2)
    c3 = Conv2D(32, (3, 3), activation='elu', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(64, (3, 3), activation='elu', padding='same') (p3)
    c4 = Conv2D(64, (3, 3), activation='elu', padding='same') (c4)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(64, (3, 3), activation='elu', padding='same') (p4)
    c5 = Conv2D(64, (3, 3), activation='elu', padding='same') (c5)
    p5 = MaxPooling2D(pool_size=(2, 2)) (c5)

    c55 = Conv2D(128, (3, 3), activation='elu', padding='same') (p5)
    c55 = Conv2D(128, (3, 3), activation='elu', padding='same') (c55)

    u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c55)
    u6 = concatenate([u6, c5])
    c6 = Conv2D(64, (3, 3), activation='elu', padding='same') (u6)
    c6 = Conv2D(64, (3, 3), activation='elu', padding='same') (c6)

    u71 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
    u71 = concatenate([u71, c4])
    c71 = Conv2D(32, (3, 3), activation='elu', padding='same') (u71)
    c61 = Conv2D(32, (3, 3), activation='elu', padding='same') (c71)

    u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c61)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(32, (3, 3), activation='elu', padding='same') (u7)
    c7 = Conv2D(32, (3, 3), activation='elu', padding='same') (c7)

    u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(16, (3, 3), activation='elu', padding='same') (u8)
    c8 = Conv2D(16, (3, 3), activation='elu', padding='same') (c8)

    u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(8, (3, 3), activation='elu', padding='same') (u9)
    c9 = Conv2D(8, (3, 3), activation='elu', padding='same') (c9)

    outputs = Conv2D(4, (1, 1), activation='sigmoid') (c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer='adam', loss=bce_dice_loss, metrics=[dice_coef])
    
    return model

# %% [markdown]
# # Training

# %%
model = build_model((256, 1600, 1))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 1600, 1) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 1600, 8) 80          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 1600, 8) 584         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 800, 8)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 800, 16) 1168        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 800, 16) 2320        conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 400, 16)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 400, 32)  4640        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 400, 32)  9248        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 200, 32)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 200, 64)  18496       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 200, 64)  36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 100, 64)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 100, 64)  36928       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 100, 64)  36928       conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 50, 64)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 50, 128)   73856       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 50, 128)   147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 100, 64)  32832       conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 100, 128) 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 100, 64)  73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 100, 64)  36928       conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 200, 32)  8224        conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 200, 96)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 200, 32)  27680       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 200, 32)  9248        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 400, 32)  4128        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 400, 64)  0           conv2d_transpose_3[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 400, 32)  18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 400, 32)  9248        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 800, 16) 2064        conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 800, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 800, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 800, 16) 2320        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 256, 1600, 8) 520         conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 256, 1600, 16 0           conv2d_transpose_5[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 1600, 8) 1160        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 1600, 8) 584         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 1600, 4) 36          conv2d_22[0][0]
# ==================================================================================================
# Total params: 600,612
# Trainable params: 600,612
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
checkpoint = ModelCheckpoint(
    '60e-Unet.h5', 
    monitor='val_dice_coef', 
    verbose=0, 
    save_best_only=True, 
    save_weights_only=False,
    mode='auto'
)

history = model.fit_generator(
    train_generator,
    validation_data=val_generator,
    callbacks=[checkpoint],
    use_multiprocessing=False,
    workers=1,
    epochs=60
)
# Out:
# Epoch 1/60
# 667/667 [==============================] - 534s 800ms/step - loss: 1.0259 - dice_coef: 0.0380 - val_loss: 1.0102 - val_dice_coef: 0.0336
# Epoch 2/60
# 667/667 [==============================] - 492s 738ms/step - loss: 0.9991 - dice_coef: 0.0504 - val_loss: 0.9591 - val_dice_coef: 0.1184
# Epoch 3/60
# 667/667 [==============================] - 493s 740ms/step - loss: 0.9279 - dice_coef: 0.1280 - val_loss: 0.9015 - val_dice_coef: 0.1566
# Epoch 4/60
# 667/667 [==============================] - 489s 733ms/step - loss: 0.8050 - dice_coef: 0.2507 - val_loss: 0.7628 - val_dice_coef: 0.2933
# Epoch 5/60
# 667/667 [==============================] - 497s 745ms/step - loss: 0.6668 - dice_coef: 0.3828 - val_loss: 0.6569 - val_dice_coef: 0.3963
# Epoch 6/60
# 667/667 [==============================] - 496s 744ms/step - loss: 0.6187 - dice_coef: 0.4277 - val_loss: 0.6259 - val_dice_coef: 0.4181
# Epoch 7/60
# 667/667 [==============================] - 494s 740ms/step - loss: 0.5866 - dice_coef: 0.4575 - val_loss: 0.6053 - val_dice_coef: 0.4409
# Epoch 8/60
# 667/667 [==============================] - 496s 744ms/step - loss: 0.5610 - dice_coef: 0.4816 - val_loss: 0.5926 - val_dice_coef: 0.4501
# Epoch 9/60
# 667/667 [==============================] - 494s 741ms/step - loss: 0.5510 - dice_coef: 0.4914 - val_loss: 0.5566 - val_dice_coef: 0.4818
# Epoch 10/60
# 667/667 [==============================] - 494s 741ms/step - loss: 0.5294 - dice_coef: 0.5112 - val_loss: 0.6067 - val_dice_coef: 0.4462
# Epoch 11/60
# 667/667 [==============================] - 474s 711ms/step - loss: 0.5049 - dice_coef: 0.5344 - val_loss: 0.5331 - val_dice_coef: 0.5073
# Epoch 12/60
# 667/667 [==============================] - 491s 736ms/step - loss: 0.5006 - dice_coef: 0.5390 - val_loss: 0.5187 - val_dice_coef: 0.5218
# Epoch 13/60
# 667/667 [==============================] - 492s 737ms/step - loss: 0.4823 - dice_coef: 0.5558 - val_loss: 0.5065 - val_dice_coef: 0.5364
# Epoch 14/60
# 667/667 [==============================] - 495s 742ms/step - loss: 0.4793 - dice_coef: 0.5589 - val_loss: 0.4919 - val_dice_coef: 0.5445
# Epoch 15/60
# 667/667 [==============================] - 493s 740ms/step - loss: 0.4701 - dice_coef: 0.5672 - val_loss: 0.4853 - val_dice_coef: 0.5479
# Epoch 16/60
# 667/667 [==============================] - 495s 743ms/step - loss: 0.4652 - dice_coef: 0.5715 - val_loss: 0.4853 - val_dice_coef: 0.5510
# Epoch 17/60
# 667/667 [==============================] - 491s 736ms/step - loss: 0.4567 - dice_coef: 0.5789 - val_loss: 0.5038 - val_dice_coef: 0.5308
# Epoch 18/60
# 667/667 [==============================] - 492s 737ms/step - loss: 0.4538 - dice_coef: 0.5820 - val_loss: 0.4963 - val_dice_coef: 0.5457
# Epoch 19/60
# 667/667 [==============================] - 491s 737ms/step - loss: 0.4472 - dice_coef: 0.5884 - val_loss: 0.5088 - val_dice_coef: 0.5302
# Epoch 20/60
# 667/667 [==============================] - 493s 738ms/step - loss: 0.4401 - dice_coef: 0.5950 - val_loss: 0.4903 - val_dice_coef: 0.5446
# Epoch 21/60
# 667/667 [==============================] - 494s 741ms/step - loss: 0.4431 - dice_coef: 0.5918 - val_loss: 0.4709 - val_dice_coef: 0.5636
# Epoch 22/60
# 667/667 [==============================] - 496s 744ms/step - loss: 0.4316 - dice_coef: 0.6025 - val_loss: 0.4771 - val_dice_coef: 0.5577
# Epoch 23/60
# 667/667 [==============================] - 503s 754ms/step - loss: 0.4337 - dice_coef: 0.6007 - val_loss: 0.4794 - val_dice_coef: 0.5586
# Epoch 24/60
# 667/667 [==============================] - 493s 740ms/step - loss: 0.4242 - dice_coef: 0.6098 - val_loss: 0.4749 - val_dice_coef: 0.5580
# Epoch 25/60
# 667/667 [==============================] - 492s 737ms/step - loss: 0.4263 - dice_coef: 0.6075 - val_loss: 0.4778 - val_dice_coef: 0.5581
# Epoch 26/60
# 667/667 [==============================] - 505s 758ms/step - loss: 0.4140 - dice_coef: 0.6190 - val_loss: 0.4617 - val_dice_coef: 0.5754
# Epoch 27/60
# 667/667 [==============================] - 514s 771ms/step - loss: 0.4073 - dice_coef: 0.6253 - val_loss: 0.4633 - val_dice_coef: 0.5713
# Epoch 28/60
# 667/667 [==============================] - 498s 747ms/step - loss: 0.4019 - dice_coef: 0.6303 - val_loss: 0.4523 - val_dice_coef: 0.5828
# Epoch 29/60
# 667/667 [==============================] - 493s 739ms/step - loss: 0.4013 - dice_coef: 0.6307 - val_loss: 0.4558 - val_dice_coef: 0.5774
# Epoch 30/60
# 667/667 [==============================] - 495s 742ms/step - loss: 0.4011 - dice_coef: 0.6311 - val_loss: 0.4678 - val_dice_coef: 0.5710
# Epoch 31/60
# 667/667 [==============================] - 493s 739ms/step - loss: 0.3891 - dice_coef: 0.6421 - val_loss: 0.4643 - val_dice_coef: 0.5726
# Epoch 32/60
# 667/667 [==============================] - 497s 745ms/step - loss: 0.3938 - dice_coef: 0.6377 - val_loss: 0.4522 - val_dice_coef: 0.5840
# Epoch 33/60
# 667/667 [==============================] - 501s 752ms/step - loss: 0.3761 - dice_coef: 0.6540 - val_loss: 0.4438 - val_dice_coef: 0.5883
# Epoch 34/60
# 667/667 [==============================] - 507s 760ms/step - loss: 0.3734 - dice_coef: 0.6568 - val_loss: 0.4518 - val_dice_coef: 0.5805
# Epoch 35/60
# 667/667 [==============================] - 493s 739ms/step - loss: 0.3728 - dice_coef: 0.6571 - val_loss: 0.4452 - val_dice_coef: 0.5887
# Epoch 36/60
# 667/667 [==============================] - 498s 747ms/step - loss: 0.3668 - dice_coef: 0.6629 - val_loss: 0.4523 - val_dice_coef: 0.5849
# Epoch 37/60
# 667/667 [==============================] - 495s 742ms/step - loss: 0.3602 - dice_coef: 0.6689 - val_loss: 0.4324 - val_dice_coef: 0.5997
# Epoch 38/60
# 667/667 [==============================] - 494s 740ms/step - loss: 0.3599 - dice_coef: 0.6692 - val_loss: 0.4314 - val_dice_coef: 0.6023
# Epoch 39/60
# 667/667 [==============================] - 493s 739ms/step - loss: 0.3485 - dice_coef: 0.6795 - val_loss: 0.4365 - val_dice_coef: 0.5999
# Epoch 40/60
# 667/667 [==============================] - 493s 740ms/step - loss: 0.3581 - dice_coef: 0.6710 - val_loss: 0.4573 - val_dice_coef: 0.5780
# Epoch 41/60
# 667/667 [==============================] - 497s 745ms/step - loss: 0.3445 - dice_coef: 0.6834 - val_loss: 0.4540 - val_dice_coef: 0.5861
# Epoch 42/60
# 667/667 [==============================] - 510s 765ms/step - loss: 0.3481 - dice_coef: 0.6802 - val_loss: 0.4384 - val_dice_coef: 0.5967
# Epoch 43/60
# 667/667 [==============================] - 494s 741ms/step - loss: 0.3433 - dice_coef: 0.6848 - val_loss: 0.4329 - val_dice_coef: 0.6015
# Epoch 44/60
# 667/667 [==============================] - 495s 742ms/step - loss: 0.3471 - dice_coef: 0.6812 - val_loss: 0.4415 - val_dice_coef: 0.5933
# Epoch 45/60
# 667/667 [==============================] - 498s 746ms/step - loss: 0.3347 - dice_coef: 0.6925 - val_loss: 0.4318 - val_dice_coef: 0.6007
# Epoch 46/60
# 667/667 [==============================] - 500s 750ms/step - loss: 0.3314 - dice_coef: 0.6955 - val_loss: 0.4341 - val_dice_coef: 0.5973
# Epoch 47/60
# 667/667 [==============================] - 503s 754ms/step - loss: 0.3326 - dice_coef: 0.6944 - val_loss: 0.4302 - val_dice_coef: 0.6004
# Epoch 48/60
# 667/667 [==============================] - 499s 748ms/step - loss: 0.3303 - dice_coef: 0.6965 - val_loss: 0.4339 - val_dice_coef: 0.6024
# Epoch 49/60
# 667/667 [==============================] - 499s 748ms/step - loss: 0.3305 - dice_coef: 0.6969 - val_loss: 0.4296 - val_dice_coef: 0.6028
# Epoch 50/60
# 667/667 [==============================] - 495s 742ms/step - loss: 0.3196 - dice_coef: 0.7066 - val_loss: 0.4381 - val_dice_coef: 0.5962
# Epoch 51/60
# 667/667 [==============================] - 510s 765ms/step - loss: 0.3188 - dice_coef: 0.7072 - val_loss: 0.4238 - val_dice_coef: 0.6094
# Epoch 52/60
# 667/667 [==============================] - 493s 739ms/step - loss: 0.3143 - dice_coef: 0.7116 - val_loss: 0.4281 - val_dice_coef: 0.6062
# Epoch 53/60
# 667/667 [==============================] - 501s 751ms/step - loss: 0.3096 - dice_coef: 0.7158 - val_loss: 0.4302 - val_dice_coef: 0.6014
# Epoch 54/60
# 667/667 [==============================] - 508s 762ms/step - loss: 0.3078 - dice_coef: 0.7173 - val_loss: 0.4409 - val_dice_coef: 0.5978
# Epoch 55/60
# 667/667 [==============================] - 494s 741ms/step - loss: 0.3060 - dice_coef: 0.7191 - val_loss: 0.4412 - val_dice_coef: 0.5939
# Epoch 56/60
# 667/667 [==============================] - 501s 751ms/step - loss: 0.3034 - dice_coef: 0.7214 - val_loss: 0.4205 - val_dice_coef: 0.6124
# Epoch 57/60
# 667/667 [==============================] - 500s 750ms/step - loss: 0.3040 - dice_coef: 0.7209 - val_loss: 0.4124 - val_dice_coef: 0.6188
# Epoch 58/60
# 667/667 [==============================] - 510s 765ms/step - loss: 0.3070 - dice_coef: 0.7185 - val_loss: 0.4007 - val_dice_coef: 0.6312
# Epoch 59/60
# 667/667 [==============================] - 495s 742ms/step - loss: 0.2982 - dice_coef: 0.7268 - val_loss: 0.4041 - val_dice_coef: 0.6292
# Epoch 60/60
# 667/667 [==============================] - 494s 741ms/step - loss: 0.2880 - dice_coef: 0.7359 - val_loss: 0.4028 - val_dice_coef: 0.6311

# %% [markdown]
# # Evaluation & Submission

# %%
with open('history.json', 'w') as f:
    json.dump(history.history, f)

history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
history_df[['dice_coef', 'val_dice_coef']].plot()

# %%
model.load_weights('60e-Unet.h5')
pred_df = []

for i in range(0, test_df.shape[0], 500):
    batch_idx = list(
        range(i, min(test_df.shape[0], i + 500))
    )
    
    test_generator = DataGenerator(
        batch_idx,
        df=test_df,
        shuffle=False,
        mode='predict',
        base_path='../input/severstal-steel-defect-detection/test_images',
        target_df=sub_df,
        batch_size=1,
        n_classes=4
    )
    
    batch_pred_masks = model.predict_generator(
        test_generator, 
        workers=1,
        verbose=1,
        use_multiprocessing=False
    )
    
    for j, b in tqdm(enumerate(batch_idx)):
        filename = test_df['ImageId'].iloc[b]
        image_df = sub_df[sub_df['ImageId'] == filename].copy()
        
        pred_masks = batch_pred_masks[j, ].round().astype(int)
        pred_rles = build_rles(pred_masks)
        
        image_df['EncodedPixels'] = pred_rles
        pred_df.append(image_df)
# Out:
# 500/500 [==============================] - 7s 14ms/step
# 500it [00:08, 61.13it/s]
#   5/500 [..............................] - ETA: 7s
# 500/500 [==============================] - 7s 14ms/step
# 500it [00:08, 60.21it/s]
#   1/500 [..............................] - ETA: 8s
# 500/500 [==============================] - 7s 13ms/step
# 500it [00:08, 62.18it/s]
#   1/500 [..............................] - ETA: 12s
# 500/500 [==============================] - 7s 15ms/step
# 500it [00:08, 60.68it/s]
#   1/500 [..............................] - ETA: 7s
# 500/500 [==============================] - 7s 14ms/step
# 500it [00:08, 60.75it/s]
#   5/500 [..............................] - ETA: 10s
# 500/500 [==============================] - 7s 14ms/step
# 500it [00:08, 58.72it/s]
# 500/500 [==============================] - 7s 13ms/step
# 500it [00:08, 57.60it/s]
# 500/500 [==============================] - 7s 14ms/step
# 500it [00:08, 61.26it/s]
#   1/500 [..............................] - ETA: 9s
# 500/500 [==============================] - 7s 13ms/step
# 500it [00:08, 61.31it/s]
#   5/500 [..............................] - ETA: 6s
# 500/500 [==============================] - 7s 14ms/step
# 500it [00:08, 60.98it/s]
#   1/500 [..............................] - ETA: 7s
# 500/500 [==============================] - 7s 14ms/step
# 500it [00:08, 60.38it/s]
# 6/6 [==============================] - 0s 16ms/step
# 6it [00:00, 60.49it/s]

# %%
pred_df = pd.concat(pred_df)
pred_df.drop(columns='ImageId', inplace=True)
pred_df.to_csv('60e-Unet-submission.csv', index=False)

# %%
submission_df = pd.read_csv('../working/60e-Unet-submission.csv')
print(submission_df.shape)
submission_df.head(100)
# Out:
# (22024, 2)
#     ImageId_ClassId                                      EncodedPixels
# 0   0000f269f.jpg_1                                                NaN
# 1   0000f269f.jpg_2                                                NaN
# 2   0000f269f.jpg_3                                                NaN
# 3   0000f269f.jpg_4                                                NaN
# 4   000ccc2ac.jpg_1                                                NaN
# 5   000ccc2ac.jpg_2                                                NaN
# 6   000ccc2ac.jpg_3                                                NaN
# 7   000ccc2ac.jpg_4                                                NaN
# 8   002451917.jpg_1                                                NaN
# 9   002451917.jpg_2                                                NaN
# 10  002451917.jpg_3                                                NaN
# 11  002451917.jpg_4                                                NaN
# 12  003c5da97.jpg_1                                                NaN
# 13  003c5da97.jpg_2                                                NaN
# 14  003c5da97.jpg_3  46854 2 202658 1 212910 1 214962 1 217014 1 21...
# 15  003c5da97.jpg_4                                                NaN
# 16  0042e163f.jpg_1                                                NaN
# 17  0042e163f.jpg_2                                                NaN
# 18  0042e163f.jpg_3                                  356186 1 360282 1
# 19  0042e163f.jpg_4                                                NaN
# 20  004f40c73.jpg_1                                                NaN
# 21  004f40c73.jpg_2                                                NaN
# 22  004f40c73.jpg_3                                                NaN
# 23  004f40c73.jpg_4                                                NaN
# 24  00513039a.jpg_1                                                NaN
# 25  00513039a.jpg_2                                                NaN
# 26  00513039a.jpg_3                                                NaN
# 27  00513039a.jpg_4                                                NaN
# 28  006f39c41.jpg_1                                                NaN
# 29  006f39c41.jpg_2                                                NaN
# ..              ...                                                ...
# 70  00f3799a7.jpg_3                                                NaN
# 71  00f3799a7.jpg_4                                                NaN
# 72  0108ce457.jpg_1                                                NaN
# 73  0108ce457.jpg_2                                                NaN
# 74  0108ce457.jpg_3                                           173830 1
# 75  0108ce457.jpg_4                                                NaN
# 76  0109b68ec.jpg_1                                                NaN
# 77  0109b68ec.jpg_2                                                NaN
# 78  0109b68ec.jpg_3                                                NaN
# 79  0109b68ec.jpg_4                                                NaN
# 80  010ec96b4.jpg_1                                                NaN
# 81  010ec96b4.jpg_2                                                NaN
# 82  010ec96b4.jpg_3                                                NaN
# 83  010ec96b4.jpg_4                                                NaN
# 84  011a7e2a9.jpg_1                                                NaN
# 85  011a7e2a9.jpg_2                                                NaN
# 86  011a7e2a9.jpg_3                                                NaN
# 87  011a7e2a9.jpg_4                                                NaN
# 88  0126f74ef.jpg_1                                                NaN
# 89  0126f74ef.jpg_2                                                NaN
# 90  0126f74ef.jpg_3                                                NaN
# 91  0126f74ef.jpg_4                                                NaN
# 92  012754bbb.jpg_1                                                NaN
# 93  012754bbb.jpg_2                                                NaN
# 94  012754bbb.jpg_3                                                NaN
# 95  012754bbb.jpg_4                                                NaN
# 96  01588ee42.jpg_1                                                NaN
# 97  01588ee42.jpg_2                                                NaN
# 98  01588ee42.jpg_3                                                NaN
# 99  01588ee42.jpg_4                                                NaN
#
# [100 rows x 2 columns]
