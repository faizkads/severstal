# %%
import os
import json

import cv2
import numpy as np
import pandas as pd
import keras
from keras import layers
from keras.applications import DenseNet121, MobileNetV2
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau,EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.optimizers import Adam, Nadam
import tensorflow as tf
from tqdm import tqdm
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
#PATHS
TRAIN_IMGS = '../input/severstal-steel-defect-detection/train_images'
TEST_IMGS = '../input/severstal-steel-defect-detection/test_images/'
TEMP_TRAIN = '../tmp/train'

def create_path(path):
    if not os.path.exists(path):
        os.makedirs(path)
create_path(TEMP_TRAIN)

# %%
train_df = pd.read_csv('../input/editeddata/maskCount_df.csv')
train_df['noDefect'] = (train_df['hasMask'] == 0).astype(int)

# %%
def resize_img(imageid, path, size):
    path = f'{path}/{imageid}'
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, size)
    return img

for imageid in tqdm(train_df['ImageId']):
    img = resize_img(imageid, path = TRAIN_IMGS, size = (256, 256))
    cv2.imwrite(f'{TEMP_TRAIN}/{imageid}', img)
# Out:
# 100%|██████████| 12568/12568 [02:12<00:00, 97.15it/s]

# %%
BATCH_SIZE = 32

def create_datagen():
    return ImageDataGenerator(
        zoom_range=0.1,  # set range for random zoom
        # set mode for filling points outside the input boundaries
        fill_mode='constant',
        cval=0.,
        rotation_range=10,
        height_shift_range=0.1,
        width_shift_range=0.1,
        horizontal_flip=True,
        vertical_flip=True,
        rescale=1/255.,
        validation_split=0.15
    )
def create_flow(datagen, subset):
    return datagen.flow_from_dataframe(
        train_df, 
        directory=TEMP_TRAIN,
        x_col='ImageId', 
        y_col='noDefect', 
        class_mode='raw',
        target_size=(256, 256),
        batch_size=BATCH_SIZE,
        subset=subset
    )

# %%
data_generator = create_datagen()
train_gen = create_flow(data_generator, 'training')
val_gen = create_flow(data_generator, 'validation')
# Out:
# Found 10683 validated image filenames.
# Found 1885 validated image filenames.

# %%
def build_model():
    mobilenet = MobileNetV2(
        include_top=False,
        input_shape=(256,256,3),
        weights=(
            '../input/'
            'mobilenet-v2-keras-weights/'
            'mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5'
        )
    )
    
    model = Sequential()
    model.add(mobilenet)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(),
        metrics=['accuracy']
    )
    
    return model

# %%
model = build_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_256 (Model) (None, 8, 8, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1280)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1281
# =================================================================
# Total params: 2,259,265
# Trainable params: 2,225,153
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
total_steps = train_df.shape[0] / BATCH_SIZE

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    patience=5,
    verbose=1,
    min_lr=1e-6
)
checkpoint = ModelCheckpoint(
    'cls-model-mobilenetv2.h5', 
    monitor='val_acc', 
    verbose=1, 
    save_best_only=False, 
    save_weights_only=False,
    mode='auto'
)
history = model.fit_generator(
    train_gen,
    steps_per_epoch=total_steps * 0.85,
    validation_data=val_gen,
    validation_steps=total_steps * 0.15,
    epochs=40,
    callbacks=[checkpoint, reduce_lr]
)
# Out:
# Epoch 1/40
# 334/333 [==============================] - 196s 587ms/step - loss: 0.3887 - acc: 0.8256 - val_loss: 0.2959 - val_acc: 0.9088
#
# Epoch 00001: saving model to cls-model-mobilenetv2.h5
# Epoch 2/40
# 334/333 [==============================] - 174s 521ms/step - loss: 0.2787 - acc: 0.8837 - val_loss: 1.4846 - val_acc: 0.6520
#
# Epoch 00002: saving model to cls-model-mobilenetv2.h5
# Epoch 3/40
# 334/333 [==============================] - 174s 522ms/step - loss: 0.2572 - acc: 0.8960 - val_loss: 0.7855 - val_acc: 0.7830
#
# Epoch 00003: saving model to cls-model-mobilenetv2.h5
# Epoch 4/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2383 - acc: 0.9051 - val_loss: 1.4359 - val_acc: 0.6594
#
# Epoch 00004: saving model to cls-model-mobilenetv2.h5
# Epoch 5/40
# 334/333 [==============================] - 176s 526ms/step - loss: 0.2218 - acc: 0.9122 - val_loss: 2.8682 - val_acc: 0.4897
#
# Epoch 00005: saving model to cls-model-mobilenetv2.h5
# Epoch 6/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2034 - acc: 0.9199 - val_loss: 0.4362 - val_acc: 0.8844
#
# Epoch 00006: saving model to cls-model-mobilenetv2.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 7/40
# 334/333 [==============================] - 174s 522ms/step - loss: 0.1615 - acc: 0.9372 - val_loss: 0.3294 - val_acc: 0.8939
#
# Epoch 00007: saving model to cls-model-mobilenetv2.h5
# Epoch 8/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.1454 - acc: 0.9435 - val_loss: 0.2578 - val_acc: 0.9056
#
# Epoch 00008: saving model to cls-model-mobilenetv2.h5
# Epoch 9/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.1335 - acc: 0.9485 - val_loss: 0.1867 - val_acc: 0.9257
#
# Epoch 00009: saving model to cls-model-mobilenetv2.h5
# Epoch 10/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.1320 - acc: 0.9502 - val_loss: 0.2362 - val_acc: 0.9061
#
# Epoch 00010: saving model to cls-model-mobilenetv2.h5
# Epoch 11/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.1264 - acc: 0.9514 - val_loss: 0.2170 - val_acc: 0.9093
#
# Epoch 00011: saving model to cls-model-mobilenetv2.h5
# Epoch 12/40
# 334/333 [==============================] - 174s 521ms/step - loss: 0.1133 - acc: 0.9580 - val_loss: 0.2047 - val_acc: 0.9172
#
# Epoch 00012: saving model to cls-model-mobilenetv2.h5
# Epoch 13/40
# 334/333 [==============================] - 176s 526ms/step - loss: 0.1152 - acc: 0.9563 - val_loss: 0.1857 - val_acc: 0.9194
#
# Epoch 00013: saving model to cls-model-mobilenetv2.h5
# Epoch 14/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.1124 - acc: 0.9577 - val_loss: 0.1303 - val_acc: 0.9438
#
# Epoch 00014: saving model to cls-model-mobilenetv2.h5
# Epoch 15/40
# 334/333 [==============================] - 176s 527ms/step - loss: 0.1031 - acc: 0.9579 - val_loss: 0.1446 - val_acc: 0.9374
#
# Epoch 00015: saving model to cls-model-mobilenetv2.h5
# Epoch 16/40
# 334/333 [==============================] - 178s 532ms/step - loss: 0.1048 - acc: 0.9597 - val_loss: 0.1706 - val_acc: 0.9215
#
# Epoch 00016: saving model to cls-model-mobilenetv2.h5
# Epoch 17/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.1009 - acc: 0.9600 - val_loss: 0.1354 - val_acc: 0.9395
#
# Epoch 00017: saving model to cls-model-mobilenetv2.h5
# Epoch 18/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.0958 - acc: 0.9606 - val_loss: 0.1382 - val_acc: 0.9379
#
# Epoch 00018: saving model to cls-model-mobilenetv2.h5
# Epoch 19/40
# 334/333 [==============================] - 174s 522ms/step - loss: 0.0961 - acc: 0.9618 - val_loss: 0.1462 - val_acc: 0.9347
#
# Epoch 00019: saving model to cls-model-mobilenetv2.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 20/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.0818 - acc: 0.9693 - val_loss: 0.1020 - val_acc: 0.9528
#
# Epoch 00020: saving model to cls-model-mobilenetv2.h5
# Epoch 21/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.0859 - acc: 0.9669 - val_loss: 0.1161 - val_acc: 0.9549
#
# Epoch 00021: saving model to cls-model-mobilenetv2.h5
# Epoch 22/40
# 334/333 [==============================] - 176s 526ms/step - loss: 0.0787 - acc: 0.9690 - val_loss: 0.1275 - val_acc: 0.9491
#
# Epoch 00022: saving model to cls-model-mobilenetv2.h5
# Epoch 23/40
# 334/333 [==============================] - 174s 522ms/step - loss: 0.0794 - acc: 0.9694 - val_loss: 0.1469 - val_acc: 0.9422
#
# Epoch 00023: saving model to cls-model-mobilenetv2.h5
# Epoch 24/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.0822 - acc: 0.9681 - val_loss: 0.1262 - val_acc: 0.9491
#
# Epoch 00024: saving model to cls-model-mobilenetv2.h5
# Epoch 25/40
# 334/333 [==============================] - 174s 521ms/step - loss: 0.0754 - acc: 0.9736 - val_loss: 0.1318 - val_acc: 0.9485
#
# Epoch 00025: saving model to cls-model-mobilenetv2.h5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 26/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.0746 - acc: 0.9707 - val_loss: 0.1295 - val_acc: 0.9459
#
# Epoch 00026: saving model to cls-model-mobilenetv2.h5
# Epoch 27/40
# 334/333 [==============================] - 174s 521ms/step - loss: 0.0745 - acc: 0.9711 - val_loss: 0.1352 - val_acc: 0.9438
#
# Epoch 00027: saving model to cls-model-mobilenetv2.h5
# Epoch 28/40
# 334/333 [==============================] - 174s 520ms/step - loss: 0.0787 - acc: 0.9698 - val_loss: 0.1324 - val_acc: 0.9443
#
# Epoch 00028: saving model to cls-model-mobilenetv2.h5
# Epoch 29/40
# 334/333 [==============================] - 175s 524ms/step - loss: 0.0741 - acc: 0.9719 - val_loss: 0.1314 - val_acc: 0.9422
#
# Epoch 00029: saving model to cls-model-mobilenetv2.h5
# Epoch 30/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.0764 - acc: 0.9693 - val_loss: 0.1362 - val_acc: 0.9464
#
# Epoch 00030: saving model to cls-model-mobilenetv2.h5
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 31/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.0769 - acc: 0.9713 - val_loss: 0.1438 - val_acc: 0.9438
#
# Epoch 00031: saving model to cls-model-mobilenetv2.h5
# Epoch 32/40
# 334/333 [==============================] - 177s 529ms/step - loss: 0.0719 - acc: 0.9730 - val_loss: 0.1433 - val_acc: 0.9459
#
# Epoch 00032: saving model to cls-model-mobilenetv2.h5
# Epoch 33/40
# 334/333 [==============================] - 176s 528ms/step - loss: 0.0755 - acc: 0.9703 - val_loss: 0.1504 - val_acc: 0.9464
#
# Epoch 00033: saving model to cls-model-mobilenetv2.h5
# Epoch 34/40
# 334/333 [==============================] - 174s 522ms/step - loss: 0.0742 - acc: 0.9723 - val_loss: 0.1406 - val_acc: 0.9443
#
# Epoch 00034: saving model to cls-model-mobilenetv2.h5
# Epoch 35/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.0762 - acc: 0.9703 - val_loss: 0.1432 - val_acc: 0.9469
#
# Epoch 00035: saving model to cls-model-mobilenetv2.h5
# Epoch 36/40
# 334/333 [==============================] - 174s 522ms/step - loss: 0.0746 - acc: 0.9722 - val_loss: 0.1423 - val_acc: 0.9464
#
# Epoch 00036: saving model to cls-model-mobilenetv2.h5
# Epoch 37/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.0776 - acc: 0.9713 - val_loss: 0.1356 - val_acc: 0.9464
#
# Epoch 00037: saving model to cls-model-mobilenetv2.h5
# Epoch 38/40
# 334/333 [==============================] - 174s 521ms/step - loss: 0.0752 - acc: 0.9710 - val_loss: 0.1446 - val_acc: 0.9469
#
# Epoch 00038: saving model to cls-model-mobilenetv2.h5
# Epoch 39/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.0740 - acc: 0.9732 - val_loss: 0.1459 - val_acc: 0.9422
#
# Epoch 00039: saving model to cls-model-mobilenetv2.h5
# Epoch 40/40
# 334/333 [==============================] - 174s 520ms/step - loss: 0.0781 - acc: 0.9706 - val_loss: 0.1430 - val_acc: 0.9448
#
# Epoch 00040: saving model to cls-model-mobilenetv2.h5

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
history_df[['acc', 'val_acc']].plot()
