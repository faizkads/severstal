# %%
import os
import json

import cv2
import numpy as np
import pandas as pd
import keras
from keras import layers
from keras.applications import DenseNet121, MobileNetV2
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.optimizers import Adam, Nadam
import tensorflow as tf
from tqdm import tqdm
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
#PATHS
TRAIN_IMGS = '../input/severstal-steel-defect-detection/train_images'
TEST_IMGS = '../input/severstal-steel-defect-detection/test_images/'
TEMP_TRAIN = '../tmp/train'

def create_path(path):
    if not os.path.exists(path):
        os.makedirs(path)
create_path(TEMP_TRAIN)

# %%
train_df = pd.read_csv('../input/edited-data/maskCount_df.csv')
train_df['noDefect'] = (train_df['hasMask'] == 0).astype(int)

# %%
def resize_img(imageid, path, size):
    path = f'{path}/{imageid}'
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, size)
    return img

for imageid in tqdm(train_df['ImageId']):
    img = resize_img(imageid, path = TRAIN_IMGS, size = (256, 256))
    cv2.imwrite(f'{TEMP_TRAIN}/{imageid}', img)
# Out:
# 100%|██████████| 12568/12568 [02:42<00:00, 77.44it/s]

# %%
BATCH_SIZE = 32

def create_datagen():
    return ImageDataGenerator(
        zoom_range=0.1,  # set range for random zoom
        # set mode for filling points outside the input boundaries
        fill_mode='constant',
        cval=0.,
        rotation_range=10,
        height_shift_range=0.1,
        width_shift_range=0.1,
        horizontal_flip=True,
        vertical_flip=True,
        rescale=1/255.,
        validation_split=0.15
    )
def create_flow(datagen, subset):
    return datagen.flow_from_dataframe(
        train_df, 
        directory=TEMP_TRAIN,
        x_col='ImageId', 
        y_col='noDefect', 
        class_mode='raw',
        target_size=(256, 256),
        batch_size=BATCH_SIZE,
        subset=subset
    )

# %%
data_generator = create_datagen()
train_gen = create_flow(data_generator, 'training')
val_gen = create_flow(data_generator, 'validation')
# Out:
# Found 10683 validated image filenames.
# Found 1885 validated image filenames.

# %%
def build_model():
    mobilenet = MobileNetV2(
        include_top=False,
        input_shape=(256,256,3),
        weights=None
    )
    
    model = Sequential()
    model.add(mobilenet)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(),
        metrics=['accuracy']
    )
       
    return model

# %%
model = build_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_256 (Model) (None, 8, 8, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1280)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1281
# =================================================================
# Total params: 2,259,265
# Trainable params: 2,225,153
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
total_steps = train_df.shape[0] / BATCH_SIZE

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    patience=5,
    verbose=1,
    min_lr=1e-6
)
checkpoint = ModelCheckpoint(
    'cls-model-mobilenet.h5', 
    monitor='val_acc', 
    verbose=1, 
    save_best_only=False, 
    save_weights_only=False,
    mode='auto'
)
history = model.fit_generator(
    train_gen,
    steps_per_epoch=total_steps * 0.85,
    validation_data=val_gen,
    validation_steps=total_steps * 0.15,
    epochs=40,
    callbacks=[checkpoint, reduce_lr]
)
# Out:
# Epoch 1/40
# 334/333 [==============================] - 201s 601ms/step - loss: 0.5895 - acc: 0.6775 - val_loss: 11.1612 - val_acc: 5.3050e-04
#
# Epoch 00001: saving model to cls-model-mobilenet.h5
# Epoch 2/40
# 334/333 [==============================] - 175s 523ms/step - loss: 0.4820 - acc: 0.7574 - val_loss: 0.2353 - val_acc: 0.9634
#
# Epoch 00002: saving model to cls-model-mobilenet.h5
# Epoch 3/40
# 334/333 [==============================] - 176s 525ms/step - loss: 0.4316 - acc: 0.7933 - val_loss: 0.1489 - val_acc: 0.9549
#
# Epoch 00003: saving model to cls-model-mobilenet.h5
# Epoch 4/40
# 334/333 [==============================] - 176s 528ms/step - loss: 0.4167 - acc: 0.8024 - val_loss: 13.4664 - val_acc: 0.0122
#
# Epoch 00004: saving model to cls-model-mobilenet.h5
# Epoch 5/40
# 334/333 [==============================] - 176s 526ms/step - loss: 0.3970 - acc: 0.8110 - val_loss: 13.5798 - val_acc: 0.0143
#
# Epoch 00005: saving model to cls-model-mobilenet.h5
# Epoch 6/40
# 334/333 [==============================] - 176s 527ms/step - loss: 0.3835 - acc: 0.8235 - val_loss: 10.6621 - val_acc: 0.0117
#
# Epoch 00006: saving model to cls-model-mobilenet.h5
# Epoch 7/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.3704 - acc: 0.8312 - val_loss: 8.5312 - val_acc: 0.0981
#
# Epoch 00007: saving model to cls-model-mobilenet.h5
# Epoch 8/40
# 334/333 [==============================] - 176s 528ms/step - loss: 0.3490 - acc: 0.8445 - val_loss: 4.9905 - val_acc: 0.3098
#
# Epoch 00008: saving model to cls-model-mobilenet.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 9/40
# 334/333 [==============================] - 175s 524ms/step - loss: 0.3091 - acc: 0.8645 - val_loss: 0.6282 - val_acc: 0.8499
#
# Epoch 00009: saving model to cls-model-mobilenet.h5
# Epoch 10/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2927 - acc: 0.8763 - val_loss: 0.2875 - val_acc: 0.8997
#
# Epoch 00010: saving model to cls-model-mobilenet.h5
# Epoch 11/40
# 334/333 [==============================] - 178s 534ms/step - loss: 0.2787 - acc: 0.8834 - val_loss: 0.2049 - val_acc: 0.9109
#
# Epoch 00011: saving model to cls-model-mobilenet.h5
# Epoch 12/40
# 334/333 [==============================] - 176s 526ms/step - loss: 0.2650 - acc: 0.8897 - val_loss: 0.5904 - val_acc: 0.8186
#
# Epoch 00012: saving model to cls-model-mobilenet.h5
# Epoch 13/40
# 334/333 [==============================] - 177s 529ms/step - loss: 0.2661 - acc: 0.8901 - val_loss: 0.3954 - val_acc: 0.8265
#
# Epoch 00013: saving model to cls-model-mobilenet.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 14/40
# 334/333 [==============================] - 179s 535ms/step - loss: 0.2442 - acc: 0.9000 - val_loss: 0.2893 - val_acc: 0.8615
#
# Epoch 00014: saving model to cls-model-mobilenet.h5
# Epoch 15/40
# 334/333 [==============================] - 180s 538ms/step - loss: 0.2546 - acc: 0.8935 - val_loss: 0.2989 - val_acc: 0.8568
#
# Epoch 00015: saving model to cls-model-mobilenet.h5
# Epoch 16/40
# 334/333 [==============================] - 177s 530ms/step - loss: 0.2547 - acc: 0.8940 - val_loss: 0.2810 - val_acc: 0.8658
#
# Epoch 00016: saving model to cls-model-mobilenet.h5
# Epoch 17/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2427 - acc: 0.8992 - val_loss: 0.3197 - val_acc: 0.8472
#
# Epoch 00017: saving model to cls-model-mobilenet.h5
# Epoch 18/40
# 334/333 [==============================] - 180s 538ms/step - loss: 0.2482 - acc: 0.8976 - val_loss: 0.3446 - val_acc: 0.8403
#
# Epoch 00018: saving model to cls-model-mobilenet.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 19/40
# 334/333 [==============================] - 176s 525ms/step - loss: 0.2410 - acc: 0.8995 - val_loss: 0.3223 - val_acc: 0.8451
#
# Epoch 00019: saving model to cls-model-mobilenet.h5
# Epoch 20/40
# 334/333 [==============================] - 177s 529ms/step - loss: 0.2422 - acc: 0.8994 - val_loss: 0.3183 - val_acc: 0.8483
#
# Epoch 00020: saving model to cls-model-mobilenet.h5
# Epoch 21/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2426 - acc: 0.9008 - val_loss: 0.3165 - val_acc: 0.8467
#
# Epoch 00021: saving model to cls-model-mobilenet.h5
# Epoch 22/40
# 334/333 [==============================] - 176s 526ms/step - loss: 0.2489 - acc: 0.8987 - val_loss: 0.3091 - val_acc: 0.8499
#
# Epoch 00022: saving model to cls-model-mobilenet.h5
# Epoch 23/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2430 - acc: 0.8979 - val_loss: 0.3079 - val_acc: 0.8589
#
# Epoch 00023: saving model to cls-model-mobilenet.h5
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 24/40
# 334/333 [==============================] - 176s 526ms/step - loss: 0.2428 - acc: 0.8959 - val_loss: 0.3127 - val_acc: 0.8509
#
# Epoch 00024: saving model to cls-model-mobilenet.h5
# Epoch 25/40
# 334/333 [==============================] - 175s 524ms/step - loss: 0.2402 - acc: 0.9026 - val_loss: 0.3147 - val_acc: 0.8568
#
# Epoch 00025: saving model to cls-model-mobilenet.h5
# Epoch 26/40
# 334/333 [==============================] - 176s 527ms/step - loss: 0.2377 - acc: 0.9032 - val_loss: 0.3087 - val_acc: 0.8536
#
# Epoch 00026: saving model to cls-model-mobilenet.h5
# Epoch 27/40
# 334/333 [==============================] - 176s 527ms/step - loss: 0.2471 - acc: 0.8975 - val_loss: 0.3039 - val_acc: 0.8610
#
# Epoch 00027: saving model to cls-model-mobilenet.h5
# Epoch 28/40
# 334/333 [==============================] - 176s 528ms/step - loss: 0.2432 - acc: 0.8988 - val_loss: 0.2997 - val_acc: 0.8637
#
# Epoch 00028: saving model to cls-model-mobilenet.h5
# Epoch 29/40
# 334/333 [==============================] - 175s 524ms/step - loss: 0.2446 - acc: 0.8994 - val_loss: 0.2989 - val_acc: 0.8573
#
# Epoch 00029: saving model to cls-model-mobilenet.h5
# Epoch 30/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2477 - acc: 0.8953 - val_loss: 0.2946 - val_acc: 0.8626
#
# Epoch 00030: saving model to cls-model-mobilenet.h5
# Epoch 31/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2398 - acc: 0.9004 - val_loss: 0.3033 - val_acc: 0.8584
#
# Epoch 00031: saving model to cls-model-mobilenet.h5
# Epoch 32/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2399 - acc: 0.9047 - val_loss: 0.2948 - val_acc: 0.8546
#
# Epoch 00032: saving model to cls-model-mobilenet.h5
# Epoch 33/40
# 334/333 [==============================] - 175s 524ms/step - loss: 0.2404 - acc: 0.9000 - val_loss: 0.2945 - val_acc: 0.8568
#
# Epoch 00033: saving model to cls-model-mobilenet.h5
# Epoch 34/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2402 - acc: 0.9002 - val_loss: 0.2971 - val_acc: 0.8552
#
# Epoch 00034: saving model to cls-model-mobilenet.h5
# Epoch 35/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2416 - acc: 0.9006 - val_loss: 0.3024 - val_acc: 0.8589
#
# Epoch 00035: saving model to cls-model-mobilenet.h5
# Epoch 36/40
# 334/333 [==============================] - 176s 527ms/step - loss: 0.2457 - acc: 0.9009 - val_loss: 0.2988 - val_acc: 0.8520
#
# Epoch 00036: saving model to cls-model-mobilenet.h5
# Epoch 37/40
# 334/333 [==============================] - 175s 525ms/step - loss: 0.2441 - acc: 0.8984 - val_loss: 0.2961 - val_acc: 0.8557
#
# Epoch 00037: saving model to cls-model-mobilenet.h5
# Epoch 38/40
# 334/333 [==============================] - 176s 528ms/step - loss: 0.2383 - acc: 0.9029 - val_loss: 0.3004 - val_acc: 0.8605
#
# Epoch 00038: saving model to cls-model-mobilenet.h5
# Epoch 39/40
# 334/333 [==============================] - 177s 529ms/step - loss: 0.2394 - acc: 0.9014 - val_loss: 0.3029 - val_acc: 0.8589
#
# Epoch 00039: saving model to cls-model-mobilenet.h5
# Epoch 40/40
# 334/333 [==============================] - 176s 528ms/step - loss: 0.2397 - acc: 0.9007 - val_loss: 0.2951 - val_acc: 0.8541
#
# Epoch 00040: saving model to cls-model-mobilenet.h5

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
history_df[['acc', 'val_acc']].plot()
